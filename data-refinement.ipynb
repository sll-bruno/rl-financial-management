# %% [markdown]
# # ETL para Análise de Dados Financeiros
#
# Este notebook implementa um processo de ETL (Extração, Transformação e Carga/Visualização) para dados financeiros sintéticos.

# %% [markdown]
# ## 1. Extração (Extract)
#
# Nesta etapa, carregamos os dados. Como não temos um arquivo de dados, vamos gerar dados sintéticos de séries temporais financeiras usando `pandas` e `numpy`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configurações de estilo para os gráficos
sns.set_style("whitegrid")

data_path = "data/amzn.csv"

# Gerar dados sintéticos
data = pd.read_csv(data_path)
df = pd.DataFrame(data)

df.head()
# Out:
#                         Date      Open      High       Low     Close  \
# 0  2000-01-03 00:00:00-05:00  4.075000  4.478125  3.952344  4.468750
# 1  2000-01-04 00:00:00-05:00  4.268750  4.575000  4.087500  4.096875
# 2  2000-01-05 00:00:00-05:00  3.525000  3.756250  3.400000  3.487500
# 3  2000-01-06 00:00:00-05:00  3.565625  3.634375  3.200000  3.278125
# 4  2000-01-07 00:00:00-05:00  3.350000  3.525000  3.309375  3.478125
#
#       Volume  Dividends  Stock Splits
# 0  322352000        0.0           0.0
# 1  349748000        0.0           0.0
# 2  769148000        0.0           0.0
# 3  375040000        0.0           0.0
# 4  210108000        0.0           0.0

# %% [markdown]
# ## 2. Transformação (Transform)
#
# Aqui, processamos e limpamos os dados. Vamos:
# - Verificar valores ausentes.
# - Calcular a média móvel do preço de fechamento.
# - Calcular a variação percentual diária.

# %%
cols_to_drop = ["Dividends","Stock Splits","Volume"]

# Criar uma cópia para evitar SettingWithCopyWarning
df_transformed = df.copy()

df_transformed.dropna(inplace=True)
df_transformed = df.drop(columns=cols_to_drop)

print(df_transformed.head())
# Out:
#                         Date      Open      High       Low     Close
# 0  2000-01-03 00:00:00-05:00  4.075000  4.478125  3.952344  4.468750
# 1  2000-01-04 00:00:00-05:00  4.268750  4.575000  4.087500  4.096875
# 2  2000-01-05 00:00:00-05:00  3.525000  3.756250  3.400000  3.487500
# 3  2000-01-06 00:00:00-05:00  3.565625  3.634375  3.200000  3.278125
# 4  2000-01-07 00:00:00-05:00  3.350000  3.525000  3.309375  3.478125

# %% [markdown]
# ## 3. Carga / Visualização (Load / Visualize)
#
# Nesta etapa final, visualizamos os dados processados para análise.

# %%
# Gráfico 1: Preço de Fechamento e Média Móvel
#plt.figure(figsize=(14, 7))
#plt.plot(df_transformed['Date'], df_transformed['Close'], label='Preço de Fechamento')
#plt.plot(df_transformed['Date'], df_transformed['Moving_Average_20'], label='Média Móvel (20 dias)', linestyle='--')
#plt.title('Preço de Fechamento e Média Móvel')
#plt.xlabel('Data')
#plt.ylabel('Preço')
#plt.legend()
#plt.show()

# %%
# Gráfico 2: Retorno Diário
#plt.figure(figsize=(14, 7))
#plt.plot(df_transformed['Date'], df_transformed['Daily_Return'], label='Retorno Diário', color='green')
#plt.title('Retorno Percentual Diário')
#plt.xlabel('Data')
#plt.ylabel('Variação Percentual')
#plt.axhline(0, color='red', linestyle='--')
#plt.legend()
#plt.show()

# %%
# Gráfico 3: Volume de Negociação
#plt.figure(figsize=(14, 7))
#plt.bar(df_transformed['Date'], df_transformed['Volume'], label='Volume', color='gray')
#plt.title('Volume de Negociação Diário')
#plt.xlabel('Data')
#plt.ylabel('Volume')
#plt.legend()
#plt.show()

# %%
df_transformed.describe()
# Out:
#               Open         High          Low        Close
# count  6348.000000  6348.000000  6348.000000  6348.000000
# mean     45.413173    45.936827    44.838871    45.402222
# std      60.351036    61.022794    59.598021    60.322979
# min       0.295500     0.305000     0.275500     0.298500
# 25%       2.374875     2.426750     2.315000     2.379000
# 50%      11.711250    11.843750    11.559250    11.694250
# 75%      86.010124    86.964499    84.632126    85.944376
# max     239.020004   242.520004   238.029999   242.059998

# %%
df_transformed.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6348 entries, 0 to 6347
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    6348 non-null   str
#  1   Open    6348 non-null   float64
#  2   High    6348 non-null   float64
#  3   Low     6348 non-null   float64
#  4   Close   6348 non-null   float64
# dtypes: float64(4), str(1)
# memory usage: 248.1 KB

# %%
# Calcular o ponto de divisão (70% dos dados)
split_point = int(len(df) * 0.7)

# Dividir o DataFrame
train_df = df_transformed.iloc[:split_point]
test_df = df_transformed.iloc[split_point:]

# Salvar os DataFrames em arquivos CSV
train_df.to_csv('data/amzn_transformed_train.csv', index=False)
test_df.to_csv('data/amzn_transformed_test.csv', index=False)

print(f"Dados de treino salvos em 'data/amzn_transformed_train.csv' com {len(train_df)} registros.")
print(f"Dados de teste salvos em 'data/amzn_transformed_test.csv' com {len(test_df)} registros.")
# Out:
# Dados de treino salvos em 'data/amzn_transformed_train.csv' com 4443 registros.
# Dados de teste salvos em 'data/amzn_transformed_test.csv' com 1905 registros.
